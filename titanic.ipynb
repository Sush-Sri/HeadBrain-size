# %% [markdown]
# <a href="https://colab.research.google.com/github/Sush-Sri/HeadBrain-size/blob/master/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
downloaded = drive.CreateFile({'id':'1LCYX4R-b62YkDnP3SDHRYF4Y32zI82Q4'}) 
downloaded.GetContentFile('titanic.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import math
titanic_data=pd.read_csv('titanic.csv');
titanic_data.head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1
# 5          897         0
# 6          898         1
# 7          899         0
# 8          900         1
# 9          901         0

# %%
print(str(len(titanic_data.index)))
# Out:
# 418

# %%
sns.countplot(x="Survived",data=titanic_data)

# %%
sns.countplot(x="Survived",hue="PassengerId",data=titanic_data)

# %%
titanic_data["Survived"].plot.hist()

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %%
##datawrangling
titanic_data.isnull()
# Out:
#      PassengerId  Survived
# 0          False     False
# 1          False     False
# 2          False     False
# 3          False     False
# 4          False     False
# ..           ...       ...
# 413        False     False
# 414        False     False
# 415        False     False
# 416        False     False
# 417        False     False
#
# [418 rows x 2 columns]

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
sns.heatmap(titanic_data)

# %%
sns.heatmap(titanic_data.isnull() , yticklabels=False,cmap="viridis")

# %%
##sns.boxplt(x="Survived",y="PassengerId",data=titanic_data)
titanic_data.head(5)
# Out:
#    PassengerId
# 0          892
# 1          893
# 2          894
# 3          895
# 4          896

# %%
titanic_data.drop("Survived",axis=1,inplace=True)

# %%
titanic_data.head(50)
# Out:
#     PassengerId
# 0           892
# 1           893
# 2           894
# 3           895
# 4           896
# 5           897
# 6           898
# 7           899
# 8           900
# 9           901
# 10          902
# 11          903
# 12          904
# 13          905
# 14          906
# 15          907
# 16          908
# 17          909
# 18          910
# 19          911
# 20          912
# 21          913
# 22          914
# 23          915
# 24          916
# 25          917
# 26          918
# 27          919
# 28          920
# 29          921
# 30          922
# 31          923
# 32          924
# 33          925
# 34          926
# 35          927
# 36          928
# 37          929
# 38          930
# 39          931
# 40          932
# 41          933
# 42          934
# 43          935
# 44          936
# 45          937
# 46          938
# 47          939
# 48          940
# 49          941
